# %% [markdown]
# # Decision Tree

# %%
import sklearn as skl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prep1 import DataPreparation
from sklearn.metrics import f1_score

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedShuffleSplit
from sklearn import tree

from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.metrics import classification_report
# %matplotlib inline

# %%
prep = DataPreparation()

train_db = pd.read_csv("dataset/train_radiomics_hipocamp.csv")
test_db = pd.read_csv("dataset/test_radiomics_hipocamp.csv")
control_db = pd.read_csv("dataset/train_radiomics_occipital_CONTROL.csv")

train_db = prep.prep_train(train_db)
test_db = prep.transform(test_db)
control_db = prep.transform(control_db)

# %%
train_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 689 entries, diagnostics_Image-original_Mean to Transition
# dtypes: float64(678), int64(10), object(1)
# memory usage: 1.6+ MB

# %%
test_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 688 entries, diagnostics_Image-original_Mean to Age
# dtypes: float64(676), int64(12)
# memory usage: 537.6 KB

# %%
X = train_db.drop(columns=["Transition"]) 
y = train_db["Transition"]

# %%
X_train = pd.read_csv('prep1/train_X.csv')
X_test = pd.read_csv('prep1/test_X.csv')
y_train = pd.read_csv('prep1/train_y.csv')
y_test = pd.read_csv('prep1/test_y.csv')

# %%
clf = DecisionTreeClassifier(random_state=2024)

param_grid = {
    'criterion': ['gini'],   
    'max_depth': [10],    
    'min_samples_split': [5],   
    'min_samples_leaf': [2],    
    'max_features': ['log2']  
}

cv_strategy = StratifiedKFold(n_splits=10)

grid_search = GridSearchCV(
    estimator=clf, 
    param_grid=param_grid, 
    scoring='f1_macro',  
    cv=cv_strategy,        
    verbose=1,              
    refit=True,
    n_jobs=-1 
)

grid_search.fit(X, y)

print("Melhores parâmetros encontrados:", grid_search.best_params_)

best_model = grid_search.best_estimator_

#1_scores = cross_val_score(best_model, X, y, cv=10, scoring='f1_macro')
print("F1 Score médio com validação cruzada:", grid_search.best_score_)


best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

print("Matriz de Confusão:")
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Blues')
plt.show()

print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Melhores parâmetros encontrados: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# F1 Score médio com validação cruzada: 0.3552774806220088
# Matriz de Confusão:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#        AD-AD       0.33      0.33      0.33        12
#        CN-CN       0.52      0.63      0.57        19
#       CN-MCI       0.00      0.00      0.00         2
#       MCI-AD       0.22      0.14      0.17        14
#      MCI-MCI       0.08      0.07      0.07        14
#
#     accuracy                           0.31        61
#    macro avg       0.23      0.24      0.23        61
# weighted avg       0.30      0.31      0.30        61

# %% [markdown]
# ### Testar controlo

# %%
CX = control_db.drop(columns=["Transition"]) 
Cy = control_db["Transition"]  

control_pred = best_model.predict(CX)

control_f1_score = f1_score(Cy, control_pred, average='macro')
print("F1-Score no conjunto de controle:", control_f1_score)

# Matriz de Confusão
ConfusionMatrixDisplay.from_predictions(Cy, control_pred, cmap='Blues')
plt.show()

# Relatório de Classificação
print("\nRelatório de Classificação no conjunto de controle:")
print(classification_report(Cy, control_pred))
# Out:
# F1-Score no conjunto de controle: 0.09465334326995486
# Relatório de Classificação no conjunto de controle:
#               precision    recall  f1-score   support
#
#        AD-AD       0.16      0.35      0.22        60
#        CN-CN       0.00      0.00      0.00        96
#       CN-MCI       0.04      0.60      0.07        10
#       MCI-AD       0.50      0.06      0.11        68
#      MCI-MCI       0.27      0.04      0.07        71
#
#     accuracy                           0.11       305
#    macro avg       0.19      0.21      0.09       305
# weighted avg       0.21      0.11      0.09       305
# /home/tiagogr/miniconda3/envs/DAA/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/tiagogr/miniconda3/envs/DAA/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/tiagogr/miniconda3/envs/DAA/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Guardar o melhor modelo da Decision Tree

# %%
best_model.fit(X, y)
test_predictions = best_model.predict(test_db)

row_ids = range(1, len(test_predictions) + 1)

output_df = pd.DataFrame({
    "RowId": row_ids,
    "Result": test_predictions
})


output_df.to_csv("resultados/dt1.csv", index=False)
